# %%
pip install csv_reader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib 
matplotlib.rcParams['font.family'] = 'AppleGothic'
from IPython.display import Image

# %% [markdown]
# ## 고객 데모 정보
#
# *데이터 상세항목 <br>
# 1) cust = 고객번호 (고객의 고유식별번호) <br>
# 2) ma_fem_dv = 성별 <br>
# 3) ages = 연령대 <br>
# 4) zon_hiv = 거주지대분류코드 (지역 대분류 코드) -> 실제 지명은 공개되지 않음

# %%
data_1 = pd.read_csv('LPOINT_BIG_COMP_01_DEMO.csv')
data_1
# Out:
#              cust ma_fem_dv ages zon_hlv
# 0      M000034966        여성  40대     Z07
# 1      M000059535        여성  30대     Z12
# 2      M000136117        여성  30대     Z11
# 3      M000201112        여성  50대     Z17
# 4      M000225114        여성  40대     Z17
# ...           ...       ...  ...     ...
# 29908  M999708287        여성  40대     Z10
# 29909  M999770689        여성  30대     Z16
# 29910  M999849895        여성  20대     Z04
# 29911  M999926092        남성  30대     Z08
# 29912  M999962961        여성  50대     Z17
#
# [29913 rows x 4 columns]

# %% [markdown]
# ## 상품 구매 정보	(유통사 상품 구매 내역)
# <br>
# *데이터 상세항목 <br>
# 1) cust = 고객번호 <br>
# 2) rec_no = 영수증번호 (장바구니 식별번호로 이는 랜덤으로 분류됨) <br>
# 3) chnl_dv = 채널 구분 (1 = 오프라인, 2 = 온라인) <br>
# 4) cop_c = 제휴사 구분코드 (A01 ~ A06 = 유통사) <br>
# 5) br_c = 구매점포 구분코드 <br>
# 6) pd_c = 상품코드 <br>
# 7) de_dt = 구매 날짜 <br>
# 8) de_ht = 구매시간 (hr) <br>
# 9) buy_am = 구매 금액 <br>
# 10) buy_ct = 구매한 수량

# %%
data_2 = pd.read_csv('LPOINT_BIG_COMP_02_PDDE.csv')
data_2_sort = data_2.sort_values(by = 'de_hr', ascending = False)
data_2_sort
# Out:
# /var/folders/mt/h66m2ngd2018sg3lkd5ghq200000gn/T/ipykernel_85135/628790124.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2 = pd.read_csv('LPOINT_BIG_COMP_02_PDDE.csv')
#                cust        rct_no  chnl_dv cop_c     br_c    pd_c     de_dt  \
# 4381742  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
# 4226175  M736347559  A04099512060        1   A04  A044968  PD1330  20211012
# 4225993  M763340522  A04099401002        1   A04  A041117  PD0413  20211012
# 4225992  M763340522  A04099401002        1   A04  A041117  PD0413  20211012
# 4225975  M757233477  A04099394228        1   A04  A041205  PD1330  20211012
# ...             ...           ...      ...   ...      ...     ...       ...
# 2588348  M460794535  E02027185830        2   A02      NaN  PD0403  20210928
# 2588349  M460794535  E02027185830        2   A02      NaN  PD0413  20210928
# ...

# %% [markdown]
# ## 제휴사 이용 정보 (제휴사 서비스 이용 내역)
#
# <br>
# *데이터 상세항목<br>
# 1) cop_c = 제휴사 (B01 = 숙박업종, C01-2 = 엔터테인먼트, D01-2 = F&B, E01 = 렌털 업종)<br>
# 2) br_c = 점포코드 <br>
# 3) de_dt = 이용일자 <br>
# 4) vst_dt = 방문일자  <br>
# 6) de_hr = 이용시간 <br>

# %%
data_3 = pd.read_csv('LPOINT_BIG_COMP_03_COP_U.csv')
data_3
# Out:
#               cust              rct_no cop_c     br_c  chnl_dv     de_dt  \
# 0       M839993508  21102612B015763935   B01  B010012        1  20211026
# 1       M839993508  21110610B014219744   B01  B010012        1  20211106
# 2       M839993508  21021112B013419710   B01  B010012        1  20210211
# 3       M839993508  21092010B012637545   B01  B010012        1  20210920
# 4       M839993508  21101009D015920171   D01  D010614        1  20211010
# ...            ...                 ...   ...      ...      ...       ...
# 248299  M058650684  21111614C021426818   C02  C020002        1  20211116
# 248300  M058650684  21111619C023223432   C02  C020002        1  20211116
# 248301  M014154595  21121209C015324520   C01  C010087        2  20211212
# 248302  M510878172  21112719C013369102   C01  C010007        2  20211127
# 248303  M761634870  21122419C013829696   C01  C010014        2  20211224
#
#           vst_dt  de_hr  buy_am
# 0       20211026     12   60000
# ...

# %% [markdown]
# ## 상품 분류 정보	(유통사 상품 카테고리 마스터)
#
# <br>
# *데이터 상세항목 <br>
# 1)pd_c = 상품코드 <br>
# 2)pd_nm = 상품명 <br>
# 3)clac_hlv_nm = 상품카테고리중분류 <br>
# 4)clac_mcls_nm = 상품카테고리대분류 <br>

# %%
data_4 = pd.read_csv('LPOINT_BIG_COMP_04_PD_CLAC.csv')
data_4
# Out:
#         pd_c     pd_nm clac_hlv_nm clac_mcls_nm
# 0     PD0001        소파          가구         거실가구
# 1     PD0002   스툴/리빙의자          가구         거실가구
# 2     PD0003        탁자          가구         거실가구
# 3     PD0004   장식장/진열장          가구         거실가구
# 4     PD0005      기타가구          가구         기타가구
# ...      ...       ...         ...          ...
# 1928  PD1929      여성향수    화장품/뷰티케어           향수
# 1929  PD1930      남성향수    화장품/뷰티케어           향수
# 1930  PD1931    남녀공용향수    화장품/뷰티케어           향수
# 1931  PD1932    남성향수세트    화장품/뷰티케어           향수
# 1932  PD1933  남녀공용향수세트    화장품/뷰티케어           향수
#
# [1933 rows x 4 columns]

# %% [markdown]
# ## 점포 정보 (유통사/제휴사 점포 마스터)
#
# *데이터 상세항목 <br>
# 1) zon_hlv = 지역 대분류 코드 -> 총 17개야 그러면 아마도 도단위로 유추가 가능할 거 같아<br>
# 2) zon_mcls = 지역 중분류 코드

# %%
data_5 = pd.read_csv('LPOINT_BIG_COMP_05_BR.csv')
data_5_sort = data_5.sort_values(by = 'zon_hlv', ascending = False)
data_5_sort
# Out:
#          br_c cop_c zon_hlv zon_mcls
# 0     A010001   A01     Z17   Z17024
# 1390  A040722   A04     Z17   Z17001
# 1403  A040735   A04     Z17   Z17001
# 1402  A040734   A04     Z17   Z17001
# 1401  A040733   A04     Z17   Z17001
# ...       ...   ...     ...      ...
# 2173  A041505   A04     Z01   Z01005
# 2172  A041504   A04     Z01   Z01005
# 2171  A041503   A04     Z01   Z01005
# 2170  A041502   A04     Z01   Z01005
# 2460  A041792   A04     Z01   Z01001
#
# [8808 rows x 4 columns]

# %% [markdown]
# ## 엘페이 이용 (엘페이 결제 내역)
#
# *데이터 상세항목 <br>
# 1) cop_c = 제휴사 (L00 = 기타 제휴사, L01 = 비제휴사) <br>

# %%
data_6 = pd.read_csv('LPOINT_BIG_COMP_06_LPAY.csv')
data_6.sort_values(by = 'buy_am', ascending = True)
# Out:
#               cust           rct_no cop_c  chnl_dv     de_dt  de_hr    buy_am
# 99201   M581613881  210627120185788   L01        1  20210627     12         5
# 153144  M844879739  211206000162968   L01        2  20211206      0        10
# 61883   M844879739  211203000128567   L01        2  20211203      0        10
# 125112  M844879739  211204000106027   L01        2  20211204      0        10
# 229683  M844879739  211202010150236   L01        2  20211202      1        10
# ...            ...              ...   ...      ...       ...    ...       ...
# 319261  M319930340  210606130142736   A01        1  20210606     13  27550000
# 257659  M084516911  210828100186901   L01        2  20210828     10  28570953
# 312548  M619205727  210901170172406   L01        2  20210901     17  30000000
# 123869  M619205727  211001170160000   L01        2  20211001     17  30000000
# 36020   M619205727  210802160180099   L01        2  20210802     16  30000000
#
# [353184 rows x 7 columns]

# %% [markdown]
# 번호	테이블 명	설명	파일 명
# 1	Demo	고객 데모 정보	LPOINT_BIG_COMP_01_DEMO.csv <br>
# 2	상품 구매 정보	유통사 상품 구매 내역	LPOINT_BIG_COMP_02_PDDE.csv <br>
# 3	제휴사 이용 정보	제휴사 서비스 이용 내역	LPOINT_BIG_COMP_03_COP_U.csv <br>
# 4	상품 분류 정보	유통사 상품 카테고리 마스터	LPOINT_BIG_COMP_04_PD_CLAC.csv <br>
# 5	점포 정보	유통사/제휴사 점포 마스터	LPOINT_BIG_COMP_05_BR.csv <br>
# 6	엘페이 이용	엘페이 결제 내역	LPOINT_BIG_COMP_06_LPAY.csv <br>

# %% [markdown]
# ## 가장 먼저 큰 손들을 파악해보자
# 상위 20%의 고객이 80%의 매출을 낸다는 파레토 법칙에 의거, 실제로 이것이 맞는지 증명해보자

# %%
data_cust = data_6.groupby(['cust'])['buy_am'].sum()
data_cust_sort = data_cust.sort_values(ascending = False)
data_cust_sort
# Out:
# cust
# M619205727    710117779
# M890280911    175271698
# M561426592    134235520
# M384121563    124813061
# M268374518     90482590
#                 ...
# M610031079          100
# M913350785          100
# M489290485          100
# M875728305          100
# M045767804          100
# Name: buy_am, Length: 8906, dtype: int64

# %%
data_cust_20 = data_cust_sort.head(int(len(data_cust_sort) * 0.2))

# %%
sum_of_buy_am_20 = data_cust_20.sum()
print(sum_of_buy_am_20)
# Out:
# 15652561451

# %%
sum_of_buy_am = data_6['buy_am'].sum()
print(sum_of_buy_am)
# Out:
# 21477751639

# %%
percent_of_20 = sum_of_buy_am_20 / sum_of_buy_am
print(percent_of_20)
# Out:
# 0.7287802612717418

# %% [markdown]
# ## 상위 구매 20%의 경향성
# 어떤 성별이며 어떤 나이대가 많고, 또한 어느 지역에 많이 분포하시는지 판단

# %%
data_cust_20
# Dictionary 형태임!
# Out:
# cust
# M619205727    710117779
# M890280911    175271698
# M561426592    134235520
# M384121563    124813061
# M268374518     90482590
#                 ...
# M754827413      3164108
# M748448862      3164037
# M344111066      3163884
# M233682456      3163094
# M515653605      3162940
# Name: buy_am, Length: 1781, dtype: int64

# %%
data_1
# Out:
#              cust ma_fem_dv ages zon_hlv
# 0      M000034966        여성  40대     Z07
# 1      M000059535        여성  30대     Z12
# 2      M000136117        여성  30대     Z11
# 3      M000201112        여성  50대     Z17
# 4      M000225114        여성  40대     Z17
# ...           ...       ...  ...     ...
# 29908  M999708287        여성  40대     Z10
# 29909  M999770689        여성  30대     Z16
# 29910  M999849895        여성  20대     Z04
# 29911  M999926092        남성  30대     Z08
# 29912  M999962961        여성  50대     Z17
#
# [29913 rows x 4 columns]

# %%
data_cust_20_2 = pd.DataFrame()
index_list = []

# %%
for cust_20 in data_cust_20.keys():
    for cust in data_1['cust']:
        if cust_20 == cust:
            index_list.append(data_1.index[data_1['cust'] == cust].tolist())
index_list = np.array(index_list).flatten().tolist()

# %%
data_cust_20_info = data_1.iloc[index_list, :]
data_cust_20_info
# Out:
#              cust ma_fem_dv ages zon_hlv
# 18631  M619205727        남성  40대     Z11
# 26730  M890280911        여성  50대     Z17
# 16887  M561426592        여성  50대     Z16
# 11565  M384121563        여성  40대     Z10
# 8062   M268374518        여성  30대     Z12
# ...           ...       ...  ...     ...
# 22708  M754827413        여성  40대     Z16
# 22514  M748448862        여성  40대     Z17
# 10379  M344111066        여성  30대     Z17
# 6986   M233682456        남성  30대     Z15
# 15489  M515653605        여성  40대     Z06
#
# [1781 rows x 4 columns]

# %%
df1 = data_cust_20_info['ma_fem_dv'].value_counts()
df1.plot.pie(autopct='%.2f%%')
plt.title("성별 비율")
plt.axis('equal')
plt.show()

# %%
data_cust_20_info['ages'].value_counts()
# Out:
# 40대    833
# 30대    507
# 50대    289
# 20대    104
# 60대     43
# 70대      5
# Name: ages, dtype: int64

# %%
data_cust_20_info['zon_hlv'].value_counts()
# Out:
# Z17    686
# Z10    457
# Z16    179
# Z04     92
# Z11     86
# Z06     53
# Z13     47
# Z14     40
# Z03     27
# Z12     23
# Z08     18
# Z15     18
# Z05     16
# Z09     12
# Z01     12
# Z07      8
# Z02      7
# Name: zon_hlv, dtype: int64

# %%
grouped_1 = data_cust_20_info.groupby(['ma_fem_dv', 'ages']).count()

# %%
grouped_1
# Out:
#                 cust  zon_hlv
# ma_fem_dv ages
# 남성        20대     31       31
#           30대    181      181
#           40대    248      248
#           50대     64       64
#           60대     10       10
#           70대      3        3
# 여성        20대     73       73
#           30대    326      326
#           40대    585      585
#           50대    225      225
#           60대     33       33
#           70대      2        2

# %%
grouped_2 = data_cust_20_info.groupby(['ma_fem_dv', 'zon_hlv']).count()

# %%
grouped_2
# Out:
#                    cust  ages
# ma_fem_dv zon_hlv
# 남성        Z01         3     3
#           Z02         4     4
#           Z03         7     7
#           Z04        24    24
#           Z05         3     3
#           Z06         8     8
#           Z07         4     4
#           Z08         7     7
#           Z09         2     2
#           Z10       148   148
#           Z11        25    25
#           Z12        10    10
#           Z13        14    14
#           Z14         8     8
#           Z15         8     8
#           Z16        42    42
#           Z17       220   220
# 여성        Z01         9     9
#           Z02         3     3
#           Z03        20    20
#           Z04        68    68
#           Z05        13    13
#           Z06        45    45
#           Z07         4     4
#           Z08        11    11
#           Z09        10    10
#           Z10       309   309
#           Z11        61    61
#           Z12        13    13
# ...

# %%
grouped_3 = data_cust_20_info.groupby(['ma_fem_dv', 'ages', 'zon_hlv']).count()

# %%
grouped_3
# Out:
#                         cust
# ma_fem_dv ages zon_hlv
# 남성        20대  Z04         4
#                Z05         1
#                Z10         5
#                Z11         1
#                Z13         2
# ...                      ...
# 여성        60대  Z11         2
#                Z14         1
#                Z16         4
#                Z17        16
#           70대  Z17         2
#
# [127 rows x 1 columns]

# %% [markdown]
# ## 상위 20%가 주로 구매한 품목

# %%
data_2
# Out:
#                cust        rct_no  chnl_dv cop_c     br_c    pd_c     de_dt  \
# 0        M430112881  A01000001113        1   A01  A010039  PD0290  20210101
# 1        M646853852  A01000002265        1   A01  A010025  PD1369  20210101
# 2        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 3        M430112881  A01000003148        1   A01  A010039  PD0290  20210101
# 4        M430112881  A01000004946        1   A01  A010039  PD0290  20210101
# ...             ...           ...      ...   ...      ...     ...       ...
# 4381738  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
# 4381739  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
# 4381740  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
# 4381741  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
# 4381742  M533286446  E06052119978        2   A06      NaN  PD0507  20211231
#
#          de_hr   buy_am  buy_ct
# ...

# %%
cust_key_20 = np.array(data_cust_20.keys()).flatten().tolist()
# Out:
# ['M619205727',
#  'M890280911',
#  'M561426592',
#  'M384121563',
#  'M268374518',
#  'M810594696',
#  'M070231934',
#  'M098304496',
#  'M274746214',
#  'M756382607',
#  'M724764678',
#  'M084516911',
#  'M731610602',
#  'M402794395',
#  'M913934979',
#  'M163773971',
#  'M506137029',
#  'M527526585',
#  'M714339488',
#  'M319930340',
#  'M787485001',
#  'M485037447',
#  'M875247933',
#  'M021121027',
#  'M161654425',
#  'M183950403',
#  'M849233011',
#  'M303975072',
#  'M441722188',
#  'M481734389',
#  'M573258118',
#  'M972399978',
#  'M951454133',
#  'M422703909',
#  'M855729596',
#  'M352414457',
#  'M892518647',
#  'M552638745',
#  'M615502219',
#  'M205795700',
#  'M209902665',
#  'M209043361',
#  'M715486567',
#  'M634882745',
#  'M020664921',
#  'M874334700',
#  'M689417445',
#  'M325787623',
#  'M581837906',
#  'M267806784',
#  'M075392188',
#  'M970943144',
#  'M109362467',
#  'M716420925',
#  'M559097269',
#  'M287243990',
#  'M405757484',
#  'M390532167',
# ...

# %%
data_cust_20_buy = data_2[data_2['cust'].isin(cust_key_20)]

# %%
data_cust_20_buy
# Out:
#                cust        rct_no  chnl_dv cop_c     br_c    pd_c     de_dt  \
# 10       M886923095  A01000010063        1   A01  A010039  PD1181  20210101
# 36       M942878878  A01000028917        1   A01  A010045  PD1699  20210101
# 37       M942878878  A01000028917        1   A01  A010045  PD1699  20210101
# 38       M942878878  A01000028917        1   A01  A010045  PD1699  20210101
# 41       M942878878  A01000030186        1   A01  A010045  PD1689  20210101
# ...             ...           ...      ...   ...      ...     ...       ...
# 4381705  M398077427  E06052102829        2   A06      NaN  PD1153  20211231
# 4381723  M816318679  E06052115831        2   A06      NaN  PD0507  20211231
# 4381724  M816318679  E06052116037        2   A06      NaN  PD0507  20211231
# 4381725  M816318679  E06052116037        2   A06      NaN  PD0507  20211231
# 4381726  M816318679  E06052116037        2   A06      NaN  PD0507  20211231
#
#          de_hr   buy_am  buy_ct
# ...

# %%
len(data_cust_20_buy)
# Out:
# 609633

# %% [markdown]
# 그럼 이들이 어느 제휴사를 주로 사용했는가?

# %%
data_cust_20_buy.value_counts('cop_c')
# Out:
# cop_c
# A02    309021
# A01    127902
# A03     87821
# A04     53293
# A06     30315
# A05      1281
# dtype: int64

# %% [markdown]
# 어떤 품목을 주로 소비했는가?

# %%
data_4
# Out:
#            pd_nm clac_hlv_nm clac_mcls_nm
# pd_c
# PD0001        소파          가구         거실가구
# PD0002   스툴/리빙의자          가구         거실가구
# PD0003        탁자          가구         거실가구
# PD0004   장식장/진열장          가구         거실가구
# PD0005      기타가구          가구         기타가구
# ...          ...         ...          ...
# PD1929      여성향수    화장품/뷰티케어           향수
# PD1930      남성향수    화장품/뷰티케어           향수
# PD1931    남녀공용향수    화장품/뷰티케어           향수
# PD1932    남성향수세트    화장품/뷰티케어           향수
# PD1933  남녀공용향수세트    화장품/뷰티케어           향수
#
# [1933 rows x 3 columns]

# %%
data_cust_20_buy_prod = data_cust_20_buy['pd_c'].value_counts()
data_cust_20_buy_prod = pd.DataFrame.from_dict(data_cust_20_buy_prod)
data_cust_20_buy_prod = data_cust_20_buy_prod.rename(columns={'pd_c':"buy_ct"})
data_cust_20_buy_prod
# Out:
#         buy_ct
# PD1156   11354
# PD0232   11172
# PD0228   10065
# PD0403    8548
# PD1486    6813
# ...        ...
# PD1238       1
# PD0281       1
# PD1121       1
# PD0915       1
# PD0522       1
#
# [1844 rows x 1 columns]

# %%
data_4_join = data_4.join(data_cust_20_buy_prod)

# %%
data_4_join
# Out:
#            pd_nm clac_hlv_nm clac_mcls_nm  buy_ct
# pd_c
# PD0001        소파          가구         거실가구   131.0
# PD0002   스툴/리빙의자          가구         거실가구    22.0
# PD0003        탁자          가구         거실가구    46.0
# PD0004   장식장/진열장          가구         거실가구    14.0
# PD0005      기타가구          가구         기타가구   150.0
# ...          ...         ...          ...     ...
# PD1929      여성향수    화장품/뷰티케어           향수   290.0
# PD1930      남성향수    화장품/뷰티케어           향수    59.0
# PD1931    남녀공용향수    화장품/뷰티케어           향수   209.0
# PD1932    남성향수세트    화장품/뷰티케어           향수     5.0
# PD1933  남녀공용향수세트    화장품/뷰티케어           향수    17.0
#
# [1933 rows x 4 columns]

# %%
data_4_join.sort_values(by = 'buy_ct', ascending = False)
# Out:
#          pd_nm clac_hlv_nm clac_mcls_nm   buy_ct
# pd_c
# PD1156    일반우유         유제품           우유  11354.0
# PD0232    일반스낵          과자          스낵류  11172.0
# PD0228    감자스낵          과자          스낵류  10065.0
# PD0403  국물봉지라면         대용식         봉지라면   8548.0
# PD1486    일반계란         축산물          계란류   6813.0
# ...        ...         ...          ...      ...
# PD1768    여성힙색        패션잡화         여성가방      NaN
# PD1777   여성오픈토        패션잡화          여성화      NaN
# PD1818   노트북가방        패션잡화        캐쥬얼가방      NaN
# PD1882   에어로빅복     헬스/피트니스         피트니스      NaN
# PD1902    기름종이    화장품/뷰티케어         미용소품      NaN
#
# [1933 rows x 4 columns]
